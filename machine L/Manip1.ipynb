# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
Data = pd.read_csv('data.csv',sep=",")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11420\2477266368.py in <module>
# ----> 1 Data = pd.read_csv('Dataset.csv',sep=",")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1232
#    1233         try:
# -> 1234             return mapping[engine](f, **self.options)
#    1235         except Exception:
#    1236             if self.handles is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      73
#      74         kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 75         self._reader = parsers.TextReader(src, **kwds)
#      76
#      77         self.unnamed_cols = self._reader.unnamed_cols
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe8 in position 69: invalid continuation byte

# %%
Data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11420\1692818959.py in <module>
# ----> 1 Data
#
# NameError: name 'Data' is not defined

# %%
df = pd.read_csv('C:\Users\PC\Documents\Dataset.csv')
print(df.to_string())
# Out:
#   File "C:\Users\PC\AppData\Local\Temp\ipykernel_11420\272520275.py", line 1
#     df = pd.read_csv('C:\Users\PC\Documents\Dataset.csv')
#                                                         ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
Data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11420\1692818959.py in <module>
# ----> 1 Data
#
# NameError: name 'Data' is not defined

# %%
Data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11420\1692818959.py in <module>
# ----> 1 Data
#
# NameError: name 'Data' is not defined

# %%
Data = pd.read_csv('data.csv',sep=",")

# %%
Data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
Data = pd.read_csv('data.csv',sep=",")

# %%
Data2 = pd.read_csv('dataset.csv',sep=",")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11420\733757166.py in <module>
# ----> 1 Data2 = pd.read_csv('dataset.csv',sep=",")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1232
#    1233         try:
# -> 1234             return mapping[engine](f, **self.options)
#    1235         except Exception:
#    1236             if self.handles is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      73
#      74         kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 75         self._reader = parsers.TextReader(src, **kwds)
#      76
#      77         self.unnamed_cols = self._reader.unnamed_cols
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 551: invalid continuation byte

# %%
Data2 = pd.read_csv('avito_car_dataset_ALL.csv',sep=",", encoding='latin-1')

# %%
Data2.Lien
# Out:
# 0        https://www.avito.ma/fr/massira_2/voitures/FIA...
# 1        https://www.avito.ma/fr/temara/voitures/Dacia_...
# 2        https://www.avito.ma/fr/casablanca/voitures/Da...
# 3        https://www.avito.ma/fr/casablanca/voitures/to...
# 4        https://www.avito.ma/fr/dakhla/voitures/Toyota...
#                                ...
# 24766    https://www.avito.ma/fr/gueliz/voitures/Mini_C...
# 24767    https://www.avito.ma/fr/safi/voitures/mini_coo...
# 24768    https://www.avito.ma/fr/sal%C3%A9/voitures/Min...
# 24769    https://www.avito.ma/fr/polo/voitures/Mini_coo...
# 24770    https://www.avito.ma/fr/marrakech/voitures/min...
# Name: Lien, Length: 24771, dtype: object

# %%
Data2
# Out:
#        Unnamed: 0                                               Lien  \
# 0               0  https://www.avito.ma/fr/massira_2/voitures/FIA...
# 1               1  https://www.avito.ma/fr/temara/voitures/Dacia_...
# 2               2  https://www.avito.ma/fr/casablanca/voitures/Da...
# 3               3  https://www.avito.ma/fr/casablanca/voitures/to...
# 4               4  https://www.avito.ma/fr/dakhla/voitures/Toyota...
# ...           ...                                                ...
# 24766       24771  https://www.avito.ma/fr/gueliz/voitures/Mini_C...
# 24767       24772  https://www.avito.ma/fr/safi/voitures/mini_coo...
# 24768       24773  https://www.avito.ma/fr/sal%C3%A9/voitures/Min...
# 24769       24774  https://www.avito.ma/fr/polo/voitures/Mini_coo...
# 24770       24775  https://www.avito.ma/fr/marrakech/voitures/min...
#
#             Ville    Secteur      Marque      Modèle  Année-Modèle  \
# 0          Temara  Massira 2        Fiat       Punto          2007
# 1          Temara        NaN       Dacia  Dokker Van          2013
# 2      Casablanca        NaN       Dacia      Dokker          2014
# 3      Casablanca        NaN  Volkswagen     Touareg          2005
# 4          Dakhla        NaN      Toyota       Prado          2007
# ...           ...        ...         ...         ...           ...
# 24766   Marrakech     Guéliz        mini      cabrio          2011
# 24767        Safi        NaN        mini      cooper          2007
# 24768        Salé        NaN        mini         one          2006
# 24769  Casablanca       Polo        mini      cooper          2010
# 24770   Marrakech        NaN        mini      cooper          2008
#
#              Kilométrage Type de carburant  Puissance fiscale  ...  \
# 0      200 000 - 249 999            Diesel                  5  ...
# 1      400 000 - 449 999            Diesel                  6  ...
# 2      160 000 - 169 999            Diesel                  6  ...
# 3              0 - 4 999            Diesel                 10  ...
# 4      200 000 - 249 999            Diesel                 12  ...
# ...                  ...               ...                ...  ...
# 24766    70 000 - 74 999           Essence                  9  ...
# 24767  190 000 - 199 999           Essence                  9  ...
# 24768    10 000 - 14 999           Essence                  8  ...
# 24769  140 000 - 149 999           Essence                  9  ...
# 24770  180 000 - 189 999           Essence                  9  ...
#
#       Caméra de recul  Vitres électriques    ABS    ESP Régulateur de vitesse  \
# 0               False               False   True  False                 False
# 1               False               False  False  False                 False
# 2               False               False  False  False                 False
# 3               False               False  False  False                 False
# 4               False               False   True  False                 False
# ...               ...                 ...    ...    ...                   ...
# 24766           False               False   True   True                 False
# 24767           False               False   True   True                 False
# 24768           False               False   True  False                 False
# 24769           False               False   True   True                 False
# 24770           False               False  False  False                 False
#
#        Limiteur de vitesse  CD/MP3/Bluetooth  Ordinateur de bord  \
# 0                    False              True               False
# 1                    False             False               False
# 2                    False             False               False
# 3                    False             False               False
# 4                    False              True               False
# ...                    ...               ...                 ...
# 24766                False             False               False
# 24767                False              True               False
# 24768                False              True               False
# 24769                False              True               False
# 24770                False             False               False
#
#        Verrouillage centralisé à distance    Prix
# 0                                   False   60000
# 1                                   False   70000
# 2                                   False   90000
# 3                                   False   90000
# 4                                   False   97000
# ...                                   ...     ...
# 24766                               False  180000
# 24767                               False   63000
# 24768                               False   60000
# 24769                               False   85000
# 24770                               False   84000
#
# [24771 rows x 32 columns]

# %%
Data.door
